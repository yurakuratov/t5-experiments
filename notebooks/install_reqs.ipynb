# %%
! pip install git+https://github.com/deepmipt/DeepPavlov.git@feat/tf2_tensorboard
# Out:
# ...
#   Cloning https://github.com/deepmipt/DeepPavlov.git (to revision feat/tf2_tensorboard) to /tmp/pip-req-build-_lrtmu8t
#   Running command git clone -q https://github.com/deepmipt/DeepPavlov.git /tmp/pip-req-build-_lrtmu8t
#   Running command git checkout -b feat/tf2_tensorboard --track origin/feat/tf2_tensorboard
#   Switched to a new branch 'feat/tf2_tensorboard'
#   Branch 'feat/tf2_tensorboard' set up to track remote branch 'feat/tf2_tensorboard' from 'origin'.
# ...
#   Using cached aio_pika-6.4.1-py3-none-any.whl (40 kB)
# ...
#   Using cached Cython-0.29.14-cp37-cp37m-manylinux1_x86_64.whl (2.1 MB)
# ...
#   Using cached fastapi-0.47.1-py3-none-any.whl (43 kB)
# ...
#   Using cached filelock-3.0.12-py3-none-any.whl (7.6 kB)
# ...
#   Using cached nltk-3.4.5-py3-none-any.whl
# ...
#   Using cached numpy-1.19.4-cp37-cp37m-manylinux2010_x86_64.whl (14.5 MB)
# ...
#   Using cached overrides-2.7.0-py3-none-any.whl
# ...
#   Using cached pandas-0.25.3-cp37-cp37m-manylinux1_x86_64.whl (10.4 MB)
# ...

# %%
! pip uninstall tensorflow-gpu -y
# Out:
# Found existing installation: tensorflow-gpu 2.3.0
# Uninstalling tensorflow-gpu-2.3.0:
#   Successfully uninstalled tensorflow-gpu-2.3.0

# %%
! pip uninstall torch torchvision -y
# Out:
# Found existing installation: torch 1.6.0+cu101
# Uninstalling torch-1.6.0+cu101:
#   Successfully uninstalled torch-1.6.0+cu101
# Found existing installation: torchvision 0.7.0+cu101
# Uninstalling torchvision-0.7.0+cu101:
#   Successfully uninstalled torchvision-0.7.0+cu101

# %%
# install torch torchvision

# %%
pip install --user torch==1.7.1+cu101 torchvision -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...
#   Using cached https://download.pytorch.org/whl/cu101/torch-1.7.1%2Bcu101-cp37-cp37m-linux_x86_64.whl (735.4 MB)
# ...
#   Using cached https://download.pytorch.org/whl/cu111/torchvision-0.9.1%2Bcu111-cp37-cp37m-linux_x86_64.whl (17.6 MB)
# ...
#   Using cached https://download.pytorch.org/whl/cu102/torchvision-0.9.1%2Bcu102-cp37-cp37m-linux_x86_64.whl (17.3 MB)
#   Using cached https://download.pytorch.org/whl/cu101/torchvision-0.9.1%2Bcu101-cp37-cp37m-linux_x86_64.whl (17.3 MB)
#   Using cached https://download.pytorch.org/whl/cpu/torchvision-0.9.1%2Bcpu-cp37-cp37m-linux_x86_64.whl (13.3 MB)
#   Using cached torchvision-0.9.1-cp37-cp37m-manylinux1_x86_64.whl (17.4 MB)
#   Using cached https://download.pytorch.org/whl/cu111/torchvision-0.9.0%2Bcu111-cp37-cp37m-linux_x86_64.whl (17.6 MB)
#   Using cached https://download.pytorch.org/whl/cu101/torchvision-0.9.0%2Bcu101-cp37-cp37m-linux_x86_64.whl (17.3 MB)
# ...

# %%
! pip install --user -r requirements.txt
# Out:
# ...
#   Using cached tensorflow-2.4.0-cp37-cp37m-manylinux2010_x86_64.whl (394.7 MB)
# ...
#   Using cached tensorflow_io-0.17.0-cp37-cp37m-manylinux2010_x86_64.whl (25.3 MB)
# ...
#   Using cached tqdm-4.49.0-py2.py3-none-any.whl (69 kB)
# ...
#   Using cached transformers-4.0.1-py3-none-any.whl (1.4 MB)
# ...
#   Using cached datasets-1.1.3-py3-none-any.whl (153 kB)
# ...
#   Using cached tfds_nightly-4.2.0.dev202103150106-py3-none-any.whl (3.8 MB)
# ...
#   Using cached pandas-1.2.3-cp37-cp37m-manylinux1_x86_64.whl (9.9 MB)
# ...
#   Using cached sacrebleu-1.5.0-py3-none-any.whl (65 kB)
# ...
#   Using cached dill-0.3.3-py2.py3-none-any.whl (81 kB)
# ...
#   Using cached xxhash-2.0.2-cp37-cp37m-manylinux2010_x86_64.whl (243 kB)
# ...
#   Using cached multiprocess-0.70.11.1-py37-none-any.whl (108 kB)
# ...
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# ...
#   Using cached tensorboard-2.5.0-py3-none-any.whl (6.0 MB)
# ...
#   Using cached tensorflow_estimator-2.4.0-py2.py3-none-any.whl (462 kB)
# ...

# %%
! horovodrun --check-build
# Out:
# 2021-05-07 11:48:07.518451: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-05-07 11:48:07.518497: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2021-05-07 11:48:16.470489: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-05-07 11:48:16.470529: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ...

# %%
! pip uninstall horovod -y
# Out:
# Found existing installation: horovod 0.21.3
# Uninstalling horovod-0.21.3:
#   Successfully uninstalled horovod-0.21.3

# %%
! pip install --user horovod==0.21.3 --upgrade
# Out:
# ...
#   Using cached horovod-0.21.3-cp37-cp37m-linux_x86_64.whl
# ...

# %%
import os
os.environ['PATH'] = os.environ['PATH'] + ':/home/jovyan/.local/bin'

# %%
! echo $PATH
# Out:
# /home/user/conda/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/home/jovyan/.local/bin

# %%
! horovodrun --check-build
# Out:
# 2021-05-07 11:49:52.831295: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-05-07 11:49:52.831347: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2021-05-07 11:50:00.434422: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2021-05-07 11:50:00.434476: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ...

# %%
! pip install --user git+https://github.com/google-research/text-to-text-transfer-transformer.git@270714ca16177921f68c660b907d9c7f0ea9ce42
# Out:
# ...
#   Cloning https://github.com/google-research/text-to-text-transfer-transformer.git (to revision 270714ca16177921f68c660b907d9c7f0ea9ce42) to /tmp/pip-req-build-36mq2wt0
#   Running command git clone -q https://github.com/google-research/text-to-text-transfer-transformer.git /tmp/pip-req-build-36mq2wt0
#   Running command git rev-parse -q --verify 'sha^270714ca16177921f68c660b907d9c7f0ea9ce42'
#   Running command git fetch -q https://github.com/google-research/text-to-text-transfer-transformer.git 270714ca16177921f68c660b907d9c7f0ea9ce42
#   Running command git checkout -q 270714ca16177921f68c660b907d9c7f0ea9ce42
# ...
#   Created wheel for t5: filename=t5-0.8.1-py3-none-any.whl size=222518 sha256=20aac62a2e67b1b080ca579c69726cb7f6bbd8ddea1ff8deee619dc9b0757b5d
#   Stored in directory: /home/jovyan/.cache/pip/wheels/c9/0d/1d/e5d2051964da0edc0209d0a1756a40df9d66e0e2224741fa0c
# Successfully built t5
# ...
